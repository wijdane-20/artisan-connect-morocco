# %% [markdown]
# <a href="https://colab.research.google.com/github/wijdane-20/artisan-connect-morocco/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense

model = Sequential([
    Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)),
    MaxPooling2D(2,2),

    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),

    Dense(128,activation='relu'),

    Dense(10,activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ...

# %%
from tensorflow.keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=5,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.0994 - loss: 2.3028 - val_accuracy: 0.0957 - val_loss: 2.3027
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.0990 - loss: 2.3028 - val_accuracy: 0.0957 - val_loss: 2.3028
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - accuracy: 0.0986 - loss: 2.3028 - val_accuracy: 0.0983 - val_loss: 2.3027
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.0953 - loss: 2.3028 - val_accuracy: 0.0983 - val_loss: 2.3028
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - accuracy: 0.0964 - loss: 2.3028 - val_accuracy: 0.0957 - val_loss: 2.3028

# %%
loss, accuracy = model.evaluate(x_test, y_test)

print("Accuracy =", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.1000 - loss: 2.3026
# Accuracy = 0.10000000149011612

# %%
print(x_train.shape)
print(y_train.shape)

print(x_train.min(), x_train.max())

print(y_train[:20])
# Out:
# (60000, 28, 28, 1)
# (60000,)
# 0.0 1.5378700499807765e-05
# [9 0 0 3 0 2 7 2 5 5 0 9 5 5 7 9 1 0 6 4]

# %%
from tensorflow.keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# %%
x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

# %%
print(x_train.min(), x_train.max())
# Out:
# 0.0 1.0

# %%
model.fit(
    x_train,
    y_train,
    epochs=5,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.8423 - loss: 0.4296 - val_accuracy: 0.8743 - val_loss: 0.3392
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8904 - loss: 0.2965 - val_accuracy: 0.8893 - val_loss: 0.2974
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9062 - loss: 0.2538 - val_accuracy: 0.8996 - val_loss: 0.2756
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9160 - loss: 0.2274 - val_accuracy: 0.8963 - val_loss: 0.2785
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9241 - loss: 0.2036 - val_accuracy: 0.9028 - val_loss: 0.2652

# %%
# !pip install keras-tuner
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 4.4 MB/s eta 0:00:00
# ...

# %%
from tensorflow.keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

# %%
import keras_tuner as kt
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D

# %%
import keras_tuner as kt
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_model(hp):

    model = Sequential()

    # Conv Layer 1
    model.add(Conv2D(
        filters=hp.Choice('filters1', [16, 32, 64]),
        kernel_size=3,
        activation='relu',
        input_shape=(28,28,1)
    ))
    model.add(MaxPooling2D())

    # Conv Layer 2
    model.add(Conv2D(
        filters=hp.Choice('filters2', [32, 64, 128]),
        kernel_size=3,
        activation='relu'
    ))
    model.add(MaxPooling2D())

    model.add(Flatten())

    # Dense Layer
    model.add(Dense(
        units=hp.Choice('dense_units', [64, 128, 256]),
        activation='relu'
    ))

    # Dropout
    model.add(Dropout(
        rate=hp.Choice('dropout', [0.2, 0.3, 0.5])
    ))

    model.add(Dense(10, activation='softmax'))

    # Learning rate
    lr = hp.Choice('lr', [1e-2, 1e-3, 1e-4])

    model.compile(
        optimizer=Adam(lr),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
tuner_random = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    directory='nas_random',
    project_name='fashion'
)

tuner_random.search(
    x_train, y_train,
    epochs=5,
    validation_split=0.2
)
# Out:
# Trial 10 Complete [00h 04m 01s]
# val_accuracy: 0.9070000052452087
#
# Best val_accuracy So Far: 0.9070000052452087
# Total elapsed time: 00h 31m 39s

# %%
tuner_hyper = kt.Hyperband(
    build_model,
    objective='val_accuracy',
    max_epochs=10,
    factor=3,
    directory='nas_hyperband',
    project_name='fashion'
)

tuner_hyper.search(
    x_train, y_train,
    epochs=5,
    validation_split=0.2
)
# Out:
# Trial 30 Complete [00h 05m 00s]
# val_accuracy: 0.9120000004768372
#
# Best val_accuracy So Far: 0.9192500114440918
# Total elapsed time: 01h 11m 39s

# %%
best_model = tuner_hyper.get_best_models(1)[0]

loss, acc = best_model.evaluate(x_test, y_test)

print("Final Accuracy:", acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9104 - loss: 0.2782
# Final Accuracy: 0.9103999733924866

# %%
import matplotlib.pyplot as plt

history = best_model.fit(x_train, y_train, epochs=5, validation_split=0.2)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Accuracy")
plt.legend(["train","val"])
plt.show()
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 49s 32ms/step - accuracy: 0.9514 - loss: 0.1299 - val_accuracy: 0.9112 - val_loss: 0.2706
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 50s 34ms/step - accuracy: 0.9557 - loss: 0.1165 - val_accuracy: 0.9138 - val_loss: 0.2712
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 50s 34ms/step - accuracy: 0.9590 - loss: 0.1088 - val_accuracy: 0.9175 - val_loss: 0.2867
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 50s 33ms/step - accuracy: 0.9614 - loss: 0.0995 - val_accuracy: 0.9134 - val_loss: 0.3316
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 49s 32ms/step - accuracy: 0.9627 - loss: 0.0952 - val_accuracy: 0.9170 - val_loss: 0.3243

# %%
import matplotlib.pyplot as plt

models = ['Manual CNN', 'NAS Hyperband']
val_acc = [90.28, 91.70]

plt.figure(figsize=(7,5))
plt.bar(models, val_acc)

plt.title('Validation Accuracy Comparison')
plt.xlabel('Models')
plt.ylabel('Accuracy (%)')

for i, v in enumerate(val_acc):
    plt.text(i, v+0.1, str(v)+'%')

plt.show()

# %%
import matplotlib.pyplot as plt

epochs = [1,2,3,4,5]

train_acc = [95.14,95.57,95.90,96.14,96.27]
val_acc   = [91.12,91.38,91.75,91.34,91.70]

plt.figure(figsize=(8,5))

plt.plot(epochs, train_acc, marker='o')
plt.plot(epochs, val_acc, marker='s')

plt.title('Accuracy Evolution of NAS Model')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend(['Training Accuracy','Validation Accuracy'])

plt.grid(True)

plt.show()
